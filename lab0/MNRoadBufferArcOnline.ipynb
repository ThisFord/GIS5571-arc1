# %% [markdown]
# ## MN Roads 10m Buffer Arc Notebook
#
#
# #### Run the next cell to connect to your GIS and get started:

# %%
from arcgis.gis import GIS
gis = GIS("home")
# Out:
# /opt/conda/lib/python3.9/site-packages/arcgis/gis/__init__.py:597: UserWarning: You are logged on as ford0161_UMN with an administrator role, proceed with caution.
#   warnings.warn(

# %%
# Item Added From Toolbar
# Title: Hennepin Co Clip Feature | Type: Feature Service | Owner: ford0161_UMN
item = gis.content.get("4936025a9b894eaa8b327a32159845b6")
item
# Out:
# <Item title:"Hennepin Co Clip Feature" type:Feature Layer Collection owner:ford0161_UMN>

# %%
from arcgis import features
features.use_proximity.create_buffers(
    item,
    distances = [10],
    field = None,
    units = 'Meters'
)
